# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code
response = requests.get(url).content
sp = soup(response, "lxml")
sp
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a2fba223d5af91496cac70d4ec3624df.css" integrity="sha512-3+HOqCwtQal5hOJQ+mdxiq5zmGOTjF6RhjDsPLxbKDYgGlLFeCwzoIanb7j5IiCuXKUqyC2q8FdkC4nmx2P2rA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code
tag= "h2"
text = [element.text for element in sp.find_all(tag)]
text
# Out:
# ['\n\n                          microsoft\n                            \n                              (Microsoft)\n                            \n ',
#  '\n\n                          jackfrued\n                            \n                              (骆昊)\n                            \n ',
#  '\n\n                          jlevy\n                            \n                              (Joshua Levy)\n                            \n ',
#  '\n\n                          jaywcjlove\n                            \n                              (小弟调调™)\n                            \n ',
#  '\n\n                          binhnguyennus\n                            \n                              (John Git)\n                            \n ',
#  '\n\n                          alibaba\n                            \n                              (Alibaba)\n                            \n ',
# ...

# %%
names = sp.find_all("h2", {'class':'f3'})
names
# Out:
# [<h2 class="f3 text-normal">
#  <a href="/microsoft">
#                            microsoft
#                              <span class="text-gray text-bold">
#                                (Microsoft)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/jackfrued">
#                            jackfrued
#                              <span class="text-gray text-bold">
#                                (骆昊)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/jlevy">
#                            jlevy
#                              <span class="text-gray text-bold">
#                                (Joshua Levy)
#                              </span>
#  </a> </h2>, <h2 class="f3 text-normal">
#  <a href="/jaywcjlove">
#                            jaywcjlove
#                              <span class="text-gray text-bold">
#                                (小弟调调™)
# ...

# %%
names[2]
# Out:
# <h2 class="f3 text-normal">
# <a href="/jlevy">
#                           jlevy
#                             <span class="text-gray text-bold">
#                               (Joshua Levy)
#                             </span>
# </a> </h2>

# %%
"""rows = [ names[x].find_all('a') for x in range(len(names)) ] 
testing = str(rows[0])"""

names2 = names[0].find('a')
cleannames = [" ".join(x.text.strip().split()) for x in names]
cleannames
# Out:
# ['microsoft (Microsoft)',
#  'jackfrued (骆昊)',
#  'jlevy (Joshua Levy)',
#  'jaywcjlove (小弟调调™)',
#  'binhnguyennus (John Git)',
#  'alibaba (Alibaba)',
#  'apache (The Apache Software Foundation)',
#  'google (Google)',
#  'seungeunrho',
#  'synox (Aravindo Wingeier)',
#  'MisterBooo (程序员吴师兄)',
#  'facebook (Facebook)',
#  'sghall (Steve Hall)',
#  'anacoimbrag (Ana Coimbra)',
#  'TheAlgorithms (The Algorithms)',
#  'afshinea (Afshine Amidi)',
#  'smooth-code (Smooth Code)',
#  'sindresorhus (Sindre Sorhus)',
#  'tensorflow',
#  'vuejs (vuejs)',
#  'flutter (Flutter)',
#  'smallnest (smallnest)',
#  'kezhenxu94 (kezhenxu94)',
#  'CyC2018',
#  'scrumpy (Scrumpy)',
#  'Product',
#  'Platform',
#  'Support',
#  'Company']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code
response = requests.get(url).content
sp = soup(response, "lxml")
sp
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-a2fba223d5af91496cac70d4ec3624df.css" integrity="sha512-3+HOqCwtQal5hOJQ+mdxiq5zmGOTjF6RhjDsPLxbKDYgGlLFeCwzoIanb7j5IiCuXKUqyC2q8FdkC4nmx2P2rA==" media="all" rel="stylesheet"/>
# ...

# %%
rep = sp.find_all("h3")

reps = rep[0].find('a')
cleanreps = [" ".join(x.text.strip().split()) for x in rep]
#here didn't need the reps (find'a' thing)
cleanreps
# Out:
# ['TheAlgorithms / Python',
#  'seungeunrho / minimalRL',
#  'apachecn / AiLearning',
#  'STVIR / pysot',
#  'ytdl-org / youtube-dl',
#  'vinta / awesome-python',
#  'tensorflow / models',
#  'facebookresearch / pythia',
#  'donnemartin / system-design-primer',
#  'ageitgey / face_recognition',
#  'shunliz / Machine-Learning',
#  'opencv / open_model_zoo',
#  'deepfakes / faceswap',
#  'thunlp / ERNIE',
#  'woj-ciech / LeakLooker',
#  'weskerfoot / DeleteFB',
#  '521xueweihan / HelloGitHub',
#  'toddmotto / public-apis',
#  'machinelearningmindset / machine-learning-course',
#  'keras-team / keras',
#  'zalando-incubator / kopf',
#  'home-assistant / home-assistant',
#  'django / django',
#  'OWASP / CheatSheetSeries',
#  'encode / django-rest-framework']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code
response = requests.get(url).content
sp = soup(response, 'lxml')
imgs = sp.find_all("img")
srclist = [img.get('src') for img in imgs]
srclistclean = ["http://" + img.strip("/") for img in srclist]
srclist

#possible to use regex to get from the html directly
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg',
#  '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Pythons_2'

# %%
#your code
response = requests.get(url).content
sp = soup(response, 'lxml')
links =  sp.find_all("href")
links
# Out:
# []

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'

# %%
#your code
response=requests.get(url).content
soup=BeautifulSoup(response,"lxml")
liste=soup.find_all('div',{"class" : "usctitlechanged"})
liste
# Out:
# [<div class="usctitlechanged" id="us/usc/t16">
#
#            Title 16 - Conservation
#
#          </div>]

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
import requests
from bs4 import BeautifulSoup

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
response = requests.get(url).content
soup = BeautifulSoup(response)
liste=soup.find_all('h3',{"class" : "title"})
#reps = rep[0].find('a')
cleanlist = [" ".join(x.text.strip().split()) for x in liste]
cleanlist
# Out:
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'RAFAEL CARO-QUINTERO',
#  'ALEXIS FLORES',
#  'SANTIAGO VILLALBA MEDEROS',
#  'LAMONT STEPHENSON']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
import pandas as pd

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code
response = requests.get(url).content
soup = BeautifulSoup(response)

# %%
tablehead=soup.find("thead")
#classlist = ['tabev6', 'tabev1', 'tabev2', 'tb_region']

cols = [colnames.text for colnames in tablehead.find_all("th")]
cols
#but we actually don't need these specific columns, because we're going to split date and time

cols2 = ["DATE", "TIME", "LATITUDE", "LONGITUDE", "REGION NAME"]

# %%
tablebod = soup.find("tbody", id="tbody")
tabletime = [times.text.strip().split() for times in soup.select("tbody td.tabev6 a")][:20]
dates = [dates[0] for dates in tabletime]
times = [times[1] for times in tabletime]
times
# Out:
# ['14:33:13.3',
#  '14:21:54.2',
#  '14:15:33.0',
#  '14:15:06.3',
#  '14:09:13.7',
#  '14:07:25.0',
#  '13:49:15.5',
#  '13:47:58.0',
#  '13:41:13.0',
#  '13:26:30.6',
#  '13:07:00.7',
#  '13:00:52.3',
#  '12:48:19.1',
#  '12:43:51.0',
#  '11:18:32.0',
#  '11:08:54.0',
#  '11:01:58.0',
#  '10:39:02.0',
#  '09:39:32.0',
#  '09:33:01.8']

# %%
tablereg = [reg.text.strip() for reg in tablebod.find_all("td", class_="tb_region")][:20]
tablereg
# Out:
# ['AZORES ISLANDS, PORTUGAL',
#  'GERMANY',
#  'NORTHERN MID-ATLANTIC RIDGE',
#  'ANTOFAGASTA, CHILE',
#  'ISLAND OF HAWAII, HAWAII',
#  'TARAPACA, CHILE',
#  'NEAR COAST OF ECUADOR',
#  'TARAPACA, CHILE',
#  'DODECANESE IS.-TURKEY BORDER REG',
#  'AZORES ISLANDS, PORTUGAL',
#  'OFFSHORE CHIAPAS, MEXICO',
#  'CENTRAL CALIFORNIA',
#  'SICILY, ITALY',
#  'CHIAPAS, MEXICO',
#  'BAJA CALIFORNIA SUR, MEXICO',
#  'AEGEAN SEA',
#  'NORTHERN COLOMBIA',
#  'SWITZERLAND',
#  'OFFSHORE OAXACA, MEXICO',
#  'OFFSHORE CHIAPAS, MEXICO']

# %%
tablecoords = [coords.text.strip() for coords in tablebod.find_all("td", class_="tabev1")][:40]
tablelats = [tablecoords[i] for i in range(0,len(tablecoords),2)] #getting the latituds 
tablelong = [tablecoords[j] for j in range(1,len(tablecoords),2)]

# %%
tablecard = [cards.text.strip() for cards in tablebod.find_all("td", class_="tabev2")][:60]
tablecard2 = [i for i in tablecard if i in ["N","S","W","E"]]  #getting rid of magnitude that was also class tabedv2
tablecardlats =[tablecard2[i] for i in range(0,len(tablecard2),2)]
tablecardlong = [tablecard2[i] for i in range(1,len(tablecard2),2)]

# %%
latitudes = zip(tablelats,tablecardlats) #zipping latitudes and cardinals together
longitudes = zip(tablelong, tablecardlong)
latitudes = [" ".join(list(lats)) for lats in latitudes]
longitudes = [" ".join(list(longs)) for longs in longitudes]

# %%
dftest = pd.DataFrame({'DATE': dates, 'TIME': times, 'LATITUDE':latitudes, 'LONGITUDE':longitudes, 'REGION':tablereg})
dftest
# Out:
#           DATE        TIME LATITUDE LONGITUDE  \
# 0   2019-05-29  14:33:13.3  40.57 N  123.81 W
# 1   2019-05-29  14:21:54.2  37.68 N   15.23 E
# 2   2019-05-29  14:15:33.0   3.02 S  140.71 E
# 3   2019-05-29  14:15:06.3  32.86 N  116.21 W
# 4   2019-05-29  14:09:13.7  43.34 N  144.42 E
# 5   2019-05-29  14:07:25.0  13.12 N   89.28 W
# 6   2019-05-29  13:49:15.5  15.14 N   92.58 W
# 7   2019-05-29  13:47:58.0  38.62 N   29.13 W
# 8   2019-05-29  13:41:13.0  14.28 N   92.74 W
# 9   2019-05-29  13:26:30.6  47.88 N    8.11 E
# 10  2019-05-29  13:07:00.7  53.02 N   30.68 W
# 11  2019-05-29  13:00:52.3  21.17 S   68.75 W
# 12  2019-05-29  12:48:19.1  19.34 N  155.12 W
# 13  2019-05-29  12:43:51.0  21.27 S   70.04 W
# 14  2019-05-29  11:18:32.0   1.39 S   80.60 W
# 15  2019-05-29  11:08:54.0  18.81 S   69.69 W
# 16  2019-05-29  11:01:58.0  36.60 N   27.67 E
# 17  2019-05-29  10:39:02.0  38.62 N   29.13 W
# 18  2019-05-29  09:39:32.0  16.05 N   94.03 W
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/search/anything/anywhere/anytime'

# %%
response = requests.get(url).content
soup = BeautifulSoup(response, "html.parser")
soup
# Out:
# <html><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>Showing anything in anywhere at anytime</title><link href="/img/favicons/favicon.png" rel="shortcut icon"/><!--THIS IS DYNAMICALLY FILLED--><meta content="website" property="og:type"/><meta content="https://hackevents.co/anything/anywhere/anytime" property="og:url"/><meta content="Showing anything in anywhere at anytime" property="og:title"/><meta content="I just found anything located in anywhere" property="og:description"/><meta content="https://hackevents.co/img/placeholder.jpg" property="og:image"/><meta content="https://hackevents.co/img/placeholder.jpg" property="og:image:secure_url"/><meta content="Showing anything in anywhere at anytime Image" property="og:image:alt"/><meta content="summary_large_image" name="twitter:card"/><meta name="twitter:domain" value="hackevents.co"/><meta name="twitter:title" value="Showin
# ...

# %%
title = [i.text for i in soup.select("div.row h3")]
city = [j.text.strip().split(",")[0] for j in soup.select("div.row p:has(i.fa-map-marker-alt)")]
country = [j.text.strip().split(",")[1] for j in soup.select("div.row p:has(i.fa-map-marker-alt)")]
when1 =[j.text.strip().split()[1] for j in soup.select("div.row p:has(i.fa-calendar-check)")]
when2 = [j.text.strip().split()[1] for j in soup.select("div.row p:has(i.fa-calendar-times)")]
when1[0]
# Out:
# '6/1/2019'

# %%
from datetime import datetime

# %%
# transforming dates into datetime objects
dtstarts = [datetime.strptime(starts, '%m/%d/%Y')for starts in when1]
dtends = [datetime.strptime(ends, '%m/%d/%Y')for ends in when2]
# calculating time delta and transforming into days
length = [(dtends[i]-dtstarts[i]).days for i in range(len(dtends))]
length
# Out:
# [0, 0, 2, 1, 0, 1, 2, 1, 2, 242]

# %%
df = pd.DataFrame({"TITLE":title, "CITY":city, "COUNTRY":country, "DATE START":when1, "DATE END":when2, "DURATION IN DAYS":length})
df
# Out:
#                                              TITLE         CITY  \
# 0                        Brigosha Hiring Hackathon   coimbatore
# 1                        Brigosha Hiring Hackathon   coimbatore
# 2                                    #apoHackathon   Düsseldorf
# 3                                    HackHunterdon   Flemington
# 4                                 EU Datathon 2019     Brussels
# 5                                          AIHacks  Los Angeles
# 6  Financial Inclusion Hack - Banking the Unbanked    Edinburgh
# 7                                   OSNA HACK 2019    Osnabrück
# 8                    Hackathon | Draper University    San Mateo
# 9                          Galileo App Competition       Prague
#
#            COUNTRY DATE START   DATE END  DURATION IN DAYS
# 0            India   6/1/2019   6/1/2019                 0
# 1            India   6/1/2019   6/1/2019                 0
# 2          Germany  5/31/2019   6/2/2019                 2
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = "https://twitter.com/barackobama"

# %%
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

# %%
what = soup.find("a", {"class":"ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-nav"})
tweet = what.find("span", {"class":"ProfileNav-value"})
total =tweet.get('data-count')
total
# Out:
# '15629'

# %%
#found better classes and tags to identify

# %%
handle = input("Input a twitter handle")
url = f"https://twitter.com/{handle}?lang=en"
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

try :
    what = soup.find("li", {"class":"ProfileNav-item--tweets"})
    tweet = what.find("span", {"class":"ProfileNav-value"})
    total =tweet.get('data-count')
    print(f"Total number of tweets for {handle} is {total}. Wow !")
except :
    print("This twitter handle doesn't exist")
# Out:
# Input a twitter handleladygaga
# Total number of tweets for ladygaga is 8963. Wow !

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
what2 = soup.find("a", {"class":"ProfileNav-stat ProfileNav-stat--link u-borderUserColor u-textCenter js-tooltip js-openSignupDialog js-nonNavigable u-textUserColor"})
tweet2 = what2.find("span", {"class":"ProfileNav-value"})

total2 =tweet2.get('data-count')
total2
# Out:
# '614027'

# %%
#found better classes and tags to identify

# %%
handle2 = input("Input a twitter handle")
url = f"https://twitter.com/{handle2}?lang=en"
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

try :
    what2 = soup.find("li", {"class":"ProfileNav-item--followers"})
    tweet2 = what2.find("span", {"class":"ProfileNav-value"})
    total2 =tweet2.get('data-count')
    total2
    print(f"{handle2} has {total2} followers. Wow, well done {handle2} !")
except :
    print("This twitter handle doesn't exist")
# Out:
# Input a twitter handleladygaga
# ladygaga has 78692446 followers. Wow, well done ladygaga !

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

# %%
for i in range(1,11):    
    firstlang = soup.find("div", class_=f"central-featured-lang lang{i}")
    langname = firstlang.strong.text
    articlenb = firstlang.small.bdi.text.replace("\xa0","")   #or split and join
    print(langname)
    print(articlenb)
# Out:
# English
# 5860000+
# Español
# 1523000+
# 日本語
# 1152000+
# Deutsch
# 2305000+
# Русский
# 1545000+
# Français
# 2107000+
# Italiano
# 1530000+
# 中文
# 1058000+
# Português
# 1006000+
# Polski
# 1338000+

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

# %%
typeofdata = soup.find_all("h2")
typename = [typen.text for typen in typeofdata]
typename
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code
response = requests.get(url).content
soup = BeautifulSoup(response, "lxml")

# %%
table = soup.find("table")
tablerows = table.find_all("tr")


cols = tablerows[0].text.strip().split("\n\n")
cols
#for rows in tablerows :
#    print(rows.text)
# Out:
# ['Rank',
#  'Rank',
#  'Language',
#  'Primary Country',
#  'TotalCountries[a]',
#  'Speakers(millions)',
#  '% of the World population\n(March 2019)[7]',
#  '\nMacrolanguage',
#  'Language familyBranch']

# %%
rows = [tablerows[i].text.strip().split("\n\n") for i in range(1,11)]
#for i in range(1,11) :
#    rows.append(tablerows[i].text.strip().split("\n\n"))
rows
# Out:
# [['—',
#   '1',
#   'Chinese (macrolanguage)',
#   'China',
#   '39',
#   '1,311',
#   '17.026',
#   '',
#   'Sino-TibetanSinitic'],
#  ['1',
#   '—',
#   'Mandarin',
#   'China',
#   '13',
#   '918',
#   '11.922',
#   'Chinese',
#   'Sino-TibetanSinitic'],
#  ['2',
#   '2',
#   'Spanish',
#   'Spain',
#   '31',
#   '460',
#   '5.974',
#   '',
#   'Indo-EuropeanRomance'],
#  ['3',
#   '3',
#   'English',
#   'United Kingdom',
#   '137',
#   '379',
#   '4.922',
#   '',
#   'Indo-EuropeanGermanic'],
#  ['4',
#   '4',
#   'Hindi',
#   'India',
#   '4',
#   '341',
#   '4.429',
#   '',
#   'Indo-EuropeanIndo-Aryan'],
#  ['—',
#   '5',
#   'Arabic (macrolanguage)',
#   'Saudi Arabia',
#   '59',
#   '319',
#   '4.143',
#   '',
#   'AfroasiaticSemitic'],
#  ['5',
#   '6',
#   'Bengali',
#   'Bangladesh',
#   '4',
#   '228',
#   '2.961',
#   '',
#   'Indo-EuropeanIndo-Aryan'],
#  ['6',
#   '7',
#   'Portuguese',
#   'Portugal',
#   '15',
#   '221',
#   '2.870',
#   '',
# ...

# %%
df = pd.DataFrame(rows, columns =cols)
dffinal= df.iloc[:,1:3]
dffinal
# Out:
#    Rank                 Language
# 0     1  Chinese (macrolanguage)
# 1     —                 Mandarin
# 2     2                  Spanish
# 3     3                  English
# 4     4                    Hindi
# 5     5   Arabic (macrolanguage)
# 6     6                  Bengali
# 7     7               Portuguese
# 8     8                  Russian
# 9     9                 Japanese
# 10    1  Chinese (macrolanguage)
# 11    —                 Mandarin
# 12    2                  Spanish
# 13    3                  English
# 14    4                    Hindi
# 15    5   Arabic (macrolanguage)
# 16    6                  Bengali
# 17    7               Portuguese
# 18    8                  Russian
# 19    9                 Japanese

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
